# %% [markdown]
# # TURNOVER OCT 2023(ANALYSIS REPORT OCT 2023)

# %% [markdown]
# ## DATE-07/12/2023                 DONE BY-VRIDDHI

# %%
#importing libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
#Defining custom autopct function for formatting percentage values
def custom_autopct(value):
    return f'{value:.2f}%'

# %%
#Data for pie chart
labels = ['UK', 'Canada', 'India', 'Russia', 'China', 'Australia', 'USA', 'France']
sizes = [29.75, 11, 3, 7, 2.5, 10.5, 19.25, 17]
#figure size with a specified data
plt.figure(figsize=(8, 8))
# Plotting the pie chart with custom colors, labels, and autopct
plt.pie(sizes, labels=labels, autopct=custom_autopct, startangle=90, colors=['lightcoral', 'lightblue', 'lightgreen', 'g', 'hotpink', 'cyan', 'brown', 'magenta'])
# Set equal aspect ratio to ensure the pie chart is circular
plt.axis('equal')
# Adjusting the layout to provide space for the title
plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)
# Adding a title to the pie chart
plt.title('Percentage Pie Chart')
# Display the pie chart
plt.show()

# %% [markdown]
# ## TURNOVER OF EACH COUNTRY

# %%
#Importing libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
#Defining custom autopct function for formatting percentage values
def custom_autopct(value):
    return f'{value:.2f}%'

# %%
#data
total_turnover = 2118077689
percentage = {'UK': 29.75, 'Canada': 11, 'India': 3, 'Russia': 7, 'China': 2.5, 'Australia': 10.5, 'USA': 19.25, 'France': 17}
country_turnover = {country: total_turnover * (percent / 100) for country, percent in percentage.items()}
# Print the turnover of each country
for country, turnover in country_turnover.items():
    print(f'Turnover in {country}: ${turnover:,.2f}')
# Out:
# Turnover in UK: $630,128,112.48
# Turnover in Canada: $232,988,545.79
# Turnover in India: $63,542,330.67
# Turnover in Russia: $148,265,438.23
# Turnover in China: $52,951,942.23
# Turnover in Australia: $222,398,157.34
# Turnover in USA: $407,729,955.13
# Turnover in France: $360,073,207.13

# %%
#calculating the turnover of each country using the percentage and total turnover of oct 2023
import matplotlib.pyplot as plt
#data
total_turnover = 2118077689
percentage = {'UK': 29.75, 'Canada': 11, 'India': 3, 'Russia': 7, 'China': 2.5, 'Australia': 10.5, 'USA': 19.25, 'France': 17}
country_turnover = {country: total_turnover * (percent / 100) for country, percent in percentage.items()}
#Plotting
fig, ax = plt.subplots(figsize=(12, 8))
colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray']
bars = ax.bar(country_turnover.keys(), country_turnover.values(), color=colors)
#Adding data labels
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval, f"${yval:,.2f}", ha='center', va='bottom', fontsize=10, color='black')
#Adding title and labels
ax.set_title('Turnover by Country - Oct 2023', fontsize=16)
ax.set_xlabel('Country', fontsize=14)
ax.set_ylabel('Turnover (in USD)', fontsize=14)
#Adding grid lines
ax.grid(axis='y', linestyle='--', alpha=0.7)
#Display the plot
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### EXPENSE OF EACH COUNTRY

# %%
#Total expense from the company
total_expense = 7501585
country_percentages = {'UK': 29.75, 'Canada': 11, 'India': 3, 'Russia': 7, 'China': 2.5, 'Australia': 10.5, 'USA': 19.25, 'France': 17}
#Creating an empty dictionary to store country expenses
country_expenses = {}
#Calculate expenses for each country based on the provided percentages
for country, percentage in country_percentages.items():
    # Calculate the expense for the current country and round off to two decimal places
    expense_for_country = round((percentage / 100) * total_expense, 2)
    # Store the rounded expense in the dictionary
    country_expenses[country] = expense_for_country
#Plotting
fig, ax = plt.subplots(figsize=(12, 8))
colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray']

bars = ax.bar(country_expenses.keys(), country_expenses.values(), color=colors)
#Adding data labels
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval, f"${yval:,.2f}", ha='center', va='bottom', fontsize=10, color='black')
#Adding title and labels
ax.set_title('Expenses by Country', fontsize=16)
ax.set_xlabel('Country', fontsize=14)
ax.set_ylabel('Expense (in USD)', fontsize=14)
#Adding grid lines
ax.grid(axis='y', linestyle='--', alpha=0.7)
#Display the plot
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### EXPENSE OF UK

# %%
# Given values
total_expense_uk = 2231721.537
total_expense_company = 7501585
marketing_expense_company = 1500000
collab_expense_company = 1000000
salary_expense_company = 4500000
other_expenses_company = 501585
# Calculate the divided expense for the UK
marketing_expense_uk = (marketing_expense_company * total_expense_uk)/total_expense_company
collab_expense_uk = (collab_expense_company * total_expense_uk) / total_expense_company
salary_expense_uk = (salary_expense_company * total_expense_uk) / total_expense_company
other_expenses_uk = (other_expenses_company * total_expense_uk) / total_expense_company
# Labels and values for the pie chart
labels = ['Marketing', 'Collab', 'Salary', 'Other']
expenses_uk = [marketing_expense_uk, collab_expense_uk, salary_expense_uk, other_expenses_uk]
# Larger size for the pie chart
fig, ax = plt.subplots(figsize=(10, 8))
colors = ['blue', 'orange', 'green', 'red']
# Create a pie chart with percentages and actual values
wedges, texts, autotexts = ax.pie(expenses_uk, labels=labels, autopct=lambda p: f'${int(p*total_expense_uk/100):,.0f} ({p:.1f}%)',
                                  startangle=90, colors=colors)
# Customize text properties
for text, autotext in zip(texts, autotexts):
    text.set_fontsize(12)
    autotext.set_fontsize(10)
# Adding title
ax.set_title('Expense Distribution for the UK')
# Display the plot
plt.show()

# %% [markdown]
# ### EXPENSE OF USA

# %%
#Given values
total_expense_USA = 1444055.11
total_expense_company = 7501585
marketing_expense_company = 1500000
collab_expense_company = 1000000
salary_expense_company = 4500000
other_expenses_company = 501585
# Calculate the divided expense for the USA
marketing_expense_USA = (marketing_expense_company * total_expense_USA)/total_expense_company
collab_expense_USA = (collab_expense_company * total_expense_USA) / total_expense_company
salary_expense_USA = (salary_expense_company * total_expense_USA) / total_expense_company
other_expenses_USA = (other_expenses_company * total_expense_USA) / total_expense_company
# Labels and values for the pie chart
labels = ['Marketing', 'Collab', 'Salary', 'Other']
expenses_USA = [marketing_expense_USA, collab_expense_USA, salary_expense_USA, other_expenses_USA]
# Larger size for the pie chart
fig, ax = plt.subplots(figsize=(10, 8))
colors = ['blue', 'orange', 'green', 'red']
# Create a pie chart with percentages and actual values as labels
wedges, texts, autotexts = ax.pie(expenses_USA, labels=labels,
                                  autopct=lambda p: f'${int(p*total_expense_USA/100):,.0f}\n({p:.1f}%)',
                                  startangle=90, colors=colors)
# Customize text properties
for text, autotext in zip(texts, autotexts):
    text.set_fontsize(12)
    autotext.set_fontsize(10)
# Adding title
ax.set_title('Expense Distribution for the USA')
# Display the plot
plt.show()

# %% [markdown]
# ### EXPENSE OF FRANCE

# %%
#Given values
total_expense_FRANCE= 1275269.450
total_expense_company = 7501585
marketing_expense_company = 1500000
collab_expense_company = 1000000
salary_expense_company = 4500000
other_expenses_company = 501585
# Calculate the divided expense for the FRANCE
marketing_expense_FRANCE = (marketing_expense_company * total_expense_FRANCE)/total_expense_company
collab_expense_FRANCE = (collab_expense_company * total_expense_FRANCE) / total_expense_company
salary_expense_FRANCE = (salary_expense_company * total_expense_FRANCE) / total_expense_company
other_expenses_FRANCE = (other_expenses_company * total_expense_FRANCE) / total_expense_company
# Labels and values for the pie chart
labels = ['Marketing', 'Collab', 'Salary', 'Other']
expenses_FRANCE = [marketing_expense_FRANCE, collab_expense_FRANCE, salary_expense_FRANCE, other_expenses_FRANCE]
# Larger size for the pie chart
fig, ax = plt.subplots(figsize=(10, 8))
colors = ['blue', 'orange', 'green', 'red']
# Create a pie chart with percentages and actual values as labels
wedges, texts, autotexts = ax.pie(expenses_FRANCE, labels=labels,
                                  autopct=lambda p: f'${int(p*total_expense_FRANCE/100):,.0f}\n({p:.1f}%)',
                                  startangle=90, colors=colors)
# Customize text properties
for text, autotext in zip(texts, autotexts):
    text.set_fontsize(12)
    autotext.set_fontsize(10)
# Adding title
ax.set_title('Expense Distribution for FRANCE')
# Display the plot
plt.show()

# %% [markdown]
# ### EXPENSE OF CANADA

# %%
#Given values
total_expense_CANADA=  825174.35
total_expense_company = 7501585
marketing_expense_company = 1500000
collab_expense_company = 1000000
salary_expense_company = 4500000
other_expenses_company = 501585
# Calculate the divided expense for the CANADA
marketing_expense_CANADA = (marketing_expense_company * total_expense_CANADA)/total_expense_company
collab_expense_CANADA = (collab_expense_company * total_expense_CANADA) / total_expense_company
salary_expense_CANADA = (salary_expense_company * total_expense_CANADA) / total_expense_company
other_expenses_CANADA = (other_expenses_company * total_expense_CANADA) / total_expense_company
# Labels and values for the pie chart
labels = ['Marketing', 'Collab', 'Salary', 'Other']
expenses_CANADA = [marketing_expense_CANADA, collab_expense_CANADA, salary_expense_CANADA, other_expenses_CANADA]
# Larger size for the pie chart
fig, ax = plt.subplots(figsize=(10, 8))
colors = ['blue', 'orange', 'green', 'red']
# Create a pie chart with percentages and actual values as labels
wedges, texts, autotexts = ax.pie(expenses_CANADA, labels=labels,
                                  autopct=lambda p: f'${int(p*total_expense_CANADA/100):,.0f}\n({p:.1f}%)',
                                  startangle=90, colors=colors)
# Customize text properties
for text, autotext in zip(texts, autotexts):
    text.set_fontsize(12)
    autotext.set_fontsize(10)
# Adding title
ax.set_title('Expense Distribution for CANADA')
# Display the plot
plt.show()

# %% [markdown]
# ### EXPENSE OF AUSTRALIA

# %%
#Given values
total_expense_AUSTRALIA=  787666.42
total_expense_company = 7501585
marketing_expense_company = 1500000
collab_expense_company = 1000000
salary_expense_company = 4500000
other_expenses_company = 501585
# Calculate the divided expense for the AUSTRALIA
marketing_expense_AUSTRALIA = (marketing_expense_company * total_expense_AUSTRALIA)/total_expense_company
collab_expense_AUSTRALIA = (collab_expense_company * total_expense_AUSTRALIA) / total_expense_company
salary_expense_AUSTRALIA = (salary_expense_company * total_expense_AUSTRALIA) / total_expense_company
other_expenses_AUSTRALIA = (other_expenses_company * total_expense_AUSTRALIA) / total_expense_company
# Labels and values for the pie chart
labels = ['Marketing', 'Collab', 'Salary', 'Other']
expenses_AUSTRALIA = [marketing_expense_AUSTRALIA, collab_expense_AUSTRALIA, salary_expense_AUSTRALIA, other_expenses_AUSTRALIA]
# Larger size for the pie chart
fig, ax = plt.subplots(figsize=(10, 8))
colors = ['blue', 'orange', 'green', 'red']
# Create a pie chart with percentages and actual values as labels
wedges, texts, autotexts = ax.pie(expenses_AUSTRALIA, labels=labels,
                                  autopct=lambda p: f'${int(p*total_expense_AUSTRALIA/100):,.0f}\n({p:.1f}%)',
                                  startangle=90, colors=colors)
# Customize text properties
for text, autotext in zip(texts, autotexts):
    text.set_fontsize(12)
    autotext.set_fontsize(10)
# Adding title
ax.set_title('Expense Distribution for AUSTRALIA')
# Display the plot
plt.show()

# %% [markdown]
# ### EXPENSES OF RUSSIA

# %%
#Given values
total_expense_RUSSIA=  525110.95
total_expense_company = 7501585
marketing_expense_company = 1500000
collab_expense_company = 1000000
salary_expense_company = 4500000
other_expenses_company = 501585
# Calculate the divided expense for the RUSSIA
marketing_expense_RUSSIA= (marketing_expense_company * total_expense_RUSSIA)/total_expense_company
collab_expense_RUSSIA = (collab_expense_company * total_expense_RUSSIA) / total_expense_company
salary_expense_RUSSIA = (salary_expense_company * total_expense_RUSSIA) / total_expense_company
other_expenses_RUSSIA = (other_expenses_company * total_expense_RUSSIA) / total_expense_company
# Labels and values for the pie chart
labels = ['Marketing', 'Collab', 'Salary', 'Other']
expenses_RUSSIA = [marketing_expense_RUSSIA, collab_expense_RUSSIA, salary_expense_RUSSIA, other_expenses_RUSSIA]
# Larger size for the pie chart
fig, ax = plt.subplots(figsize=(10, 8))
colors = ['blue', 'orange', 'green', 'red']
# Create a pie chart with percentages and actual values as labels
wedges, texts, autotexts = ax.pie(expenses_RUSSIA, labels=labels,
                                  autopct=lambda p: f'${int(p*total_expense_RUSSIA/100):,.0f}\n({p:.1f}%)',
                                  startangle=90, colors=colors)
# Customize text properties
for text, autotext in zip(texts, autotexts):
    text.set_fontsize(12)
    autotext.set_fontsize(10)
# Adding title
ax.set_title('Expense Distribution for RUSSIA')
# Display the plot
plt.show()

# %% [markdown]
# ### EXPENSE OF INDIA

# %%
#Given values
total_expense_INDIA=  225047.55
total_expense_company = 7501585
marketing_expense_company = 1500000
collab_expense_company = 1000000
salary_expense_company = 4500000
other_expenses_company = 501585
# Calculate the divided expense for the INDIA
marketing_expense_INDIA= (marketing_expense_company * total_expense_INDIA)/total_expense_company
collab_expense_INDIA = (collab_expense_company * total_expense_INDIA) / total_expense_company
salary_expense_INDIA = (salary_expense_company * total_expense_INDIA) / total_expense_company
other_expenses_INDIA = (other_expenses_company * total_expense_INDIA) / total_expense_company
# Labels and values for the pie chart
labels = ['Marketing', 'Collab', 'Salary', 'Other']
expenses_INDIA = [marketing_expense_INDIA, collab_expense_INDIA, salary_expense_INDIA, other_expenses_INDIA]
# Larger size for the pie chart
fig, ax = plt.subplots(figsize=(10, 8))
colors = ['blue', 'orange', 'green', 'red']
# Create a pie chart with percentages and actual values as labels
wedges, texts, autotexts = ax.pie(expenses_INDIA, labels=labels,
                                  autopct=lambda p: f'${int(p*total_expense_INDIA/100):,.0f}\n({p:.1f}%)',
                                  startangle=90, colors=colors)
# Customize text properties
for text, autotext in zip(texts, autotexts):
    text.set_fontsize(12)
    autotext.set_fontsize(10)
# Adding title
ax.set_title('Expense Distribution for INDIA')
# Display the plot
plt.show()

# %% [markdown]
# ### EXPENSE OF CHINA

# %%
#Given values
total_expense_CHINA=  187539.62
total_expense_company = 7501585
marketing_expense_company = 1500000
collab_expense_company = 1000000
salary_expense_company = 4500000
other_expenses_company = 501585
# Calculate the divided expense for the CHINA
marketing_expense_CHINA= (marketing_expense_company * total_expense_CHINA)/total_expense_company
collab_expense_CHINA = (collab_expense_company * total_expense_CHINA) / total_expense_company
salary_expense_CHINA = (salary_expense_company * total_expense_CHINA) / total_expense_company
other_expenses_CHINA = (other_expenses_company * total_expense_CHINA) / total_expense_company
# Labels and values for the pie chart
labels = ['Marketing', 'Collab', 'Salary', 'Other']
expenses_CHINA = [marketing_expense_CHINA, collab_expense_CHINA, salary_expense_CHINA, other_expenses_CHINA]
# Larger size for the pie chart
fig, ax = plt.subplots(figsize=(10, 8))
colors = ['blue', 'orange', 'green', 'red']
# Create a pie chart with percentages and actual values as labels
wedges, texts, autotexts = ax.pie(expenses_CHINA, labels=labels,
                                  autopct=lambda p: f'${int(p*total_expense_CHINA/100):,.0f}\n({p:.1f}%)',
                                  startangle=90, colors=colors)
# Customize text properties
for text, autotext in zip(texts, autotexts):
    text.set_fontsize(12)
    autotext.set_fontsize(10)
# Adding title
ax.set_title('Expense Distribution for CHINA')
# Display the plot
plt.show()

# %% [markdown]
# ### PROFIT OF UK

# %%
total_turnover_uk =630128112.48
total_expense_uk = 2231721.537
# Calculate the profit of the UK company
profit_uk_company = total_turnover_uk - total_expense_uk
print(f'Profit in UK: ${profit_uk_company:,.2f}')
# Out:
# Profit in UK: $627,896,390.94

# %% [markdown]
# ### PROFIT OF USA

# %%
total_turnover_USA=407729955.13
total_expense_USA = 1444055.11
# Calculate the profit of the USA company
profit_USA_company = total_turnover_USA- total_expense_USA
print(f'Profit in USA: ${profit_USA_company:,.2f}')
# Out:
# Profit in USA: $406,285,900.02

# %% [markdown]
# ### PROFIT OF FRANCE

# %%
total_turnover_france=232988545.79
total_expense_france= 825174.35
# Calculate the profit of the france company
profit_france_company = total_turnover_france - total_expense_france
print(f'Profit in Canada: ${profit_france_company:,.2f}')
# Out:
# Profit in Canada: $232,163,371.44

# %% [markdown]
# ### PROFIT OF CANADA

# %%
total_turnover_canada=232988545.79
total_expense_canada = 825174.35
# Calculate the profit of the canada company
profit_canada_company = total_turnover_canada - total_expense_canada
print(f'Profit in Canada: ${profit_canada_company:,.2f}')
# Out:
# Profit in Canada: $232,163,371.44

# %% [markdown]
# ### PROFIT OF AUSTRALIA

# %%
total_turnover_australia=222398157.34
total_expense_australia = 787666.42
# Calculate the profit of the australia company
profit_australia_company = total_turnover_australia - total_expense_australia
print(f'Profit in Australia: ${profit_australia_company:,.2f}')
# Out:
# Profit in Australia: $221,610,490.92

# %% [markdown]
# ### PROFIT OF RUSSIA

# %%
total_turnover_russia=148265438.23
total_expense_russia =525110.95
# Calculate the profit of the russia company
profit_russia_company = total_turnover_russia - total_expense_russia
print(f'Profit in Russia: ${profit_russia_company:,.2f}')
# Out:
# Profit in Russia: $147,740,327.28

# %% [markdown]
# ### PROFIT OF INDIA

# %%
total_turnover_india=63542330.67
total_expense_india =225047.55
# Calculate the profit of the india company
profit_india_company = total_turnover_india - total_expense_india
print(f'Profit in India: ${profit_india_company:,.2f}')
# Out:
# Profit in India: $63,317,283.12

# %% [markdown]
# ### PROFIT OF CHINA

# %%
total_turnover_china=52951942.23
total_expense_china =187539.62
# Calculate the profit of the china company
profit_china_company = total_turnover_china - total_expense_china
print(f'Profit in China: ${profit_china_company:,.2f}')
# Out:
# Profit in China: $52,764,402.61

# %%
import matplotlib.pyplot as plt
#Given values
countries = ['UK', 'USA', 'France', 'Canada', 'Australia', 'Russia', 'India', 'China']
profits = [627896390.94, 406285900.02, 232163371.44, 232163371.44, 221610490.92, 147740327.28, 63317283.12, 52764402.61]
#Plotting the larger bar graph
fig, ax = plt.subplots(figsize=(12, 8))
bars = ax.bar(countries, profits, color='blue')
#Adding values on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f'${int(yval):,.2f}', ha='center', va='bottom', fontsize=10)
#Adding title and labels
plt.title('Profits by Country in october')
plt.ylabel('Profit (in USD)')
plt.xlabel('Country')
#Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Given profit values for each country in October 2023
profits_october = {
    'UK': 627896390.94,
    'Canada': 232163371.44,
    'India': 63317283.12,
    'Russia': 147740327.28,
    'China': 52764402.61,
    'Australia': 221610490.92,
    'USA': 406285900.02,
    'France': 358797937.68
}

# Given profit values for each country in November 2023
profits_november = {
    'UK': 607383745.28,
    'Canada': 37961484.08,
    'India': 43655706.70,
    'Russia': 113884452.24,
    'China': 32267261.46,
    'Australia': 151845936.32,
    'USA': 379614840.80,
    'France': 531460777.12
}

# Plotting a grouped bar graph for profits in October and November 2023
bar_width = 0.35
bar_positions_october = range(len(profits_october))
bar_positions_november = [pos + bar_width for pos in bar_positions_october]

plt.bar(bar_positions_october, profits_october.values(), color='cyan', width=bar_width, label='October 2023')
plt.bar(bar_positions_november, profits_november.values(), color='black', width=bar_width, label='November 2023')

plt.xlabel('Country')
plt.ylabel('Profit ($)')
plt.title('Profit Comparison between October and November 2023')
plt.xticks([pos + bar_width / 2 for pos in bar_positions_october], profits_october.keys())
plt.legend()

plt.show()
